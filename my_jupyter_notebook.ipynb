# %% [markdown]
# # My Jupyter Notebook on IBM Data Science Experience

# %% [markdown]
# **Andre Willey**
# Personal Trainer / English Tutor

# %% [markdown]
# *I am interested in data science because I would like to learn how to process and utilize database information.*

# %% [markdown]
# ### In cell 5, the code is intended to compute a very basic mathematic equation (1+1).

# %%
1+1
# Out:
# 2

# %% [markdown]
# Using Markdown or HTML, this cell must include at least 3 of the following:
#
# --------
# -  horizontal rule
#
# --------
# - bulleted list
# - bulleted list
#
#
# 1. numbered list
# 1. tables
#
# | table head1    | table head 2   | table head 3 |
# | ---------------|----------------| -------------|
# | content1       | content4       | content7     |
# | content2       | wow            | content8     |
# | content3       | content6       | amazing      |
#
# 1. [hyperlinks](https://saltyanalysis.wordpress.com)
# 1. images ![images](https://www-03.ibm.com/press/us/en/attachment/20190.wss?fileId=ATTACH_FILE0&fileName=ibmpos_blue_thumb.jpg "image")
# 1.  <font color="red"> code/syntax highlighting</font>
# 1. > blocked quotes
# 1. ~~strikethrough~~
